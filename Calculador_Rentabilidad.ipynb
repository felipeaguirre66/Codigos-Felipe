# %% [markdown]
# # Calcula rentabilidad
# ## completar:
# ###1. costo_bruto con el costo de la caja en dolares
# ###2. dolar con el valor del dolar + 10
# ###3. unidades con la cantidad de unidades

# %%
costo_bruto = 19088
dolar = 1
#dolar = 131.23
unidades = 1
precio_venta = 28999
costo = costo_bruto*dolar
flete = 500
IIBB = 140

comision_meli = (precio_venta*1.15)-precio_venta
ganancia = precio_venta-costo/unidades-comision_meli-flete-IIBB

print(f"Poniendo {round(costo)} ganariamos {round(ganancia)} por unidad y vendiendo {unidades} unidades {round(ganancia*unidades)} en total")
# Out:
# Poniendo 19088 ganariamos 4921 por unidad y vendiendo 1 unidades 4921 en total
